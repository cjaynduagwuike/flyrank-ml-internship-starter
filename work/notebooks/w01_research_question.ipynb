# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# Lane 1: Ranking Signal Analysis
# I chose the Ranking Signal Analysis lane to explore how core observable performance metrics—such as impressions, clicks, average position, and user engagement rates—correlate with overall search visibility. By analyzing these pre-decision signals, this project will provide data-backed insights into historical user behavior without relying on pre-computed product flags. Ultimately, this analysis will help reviewers objectively determine whether updating stale text or optimizing page layouts will deliver the highest measurable impact for a client, ensuring our action recommendations are grounded purely in empirical evidence.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# My work helps internal strategy teams and human reviewers decide which organic search performance metrics serve as the most reliable, early indicators of a page's competitive health before executing a content update. By mapping the empirical relationship and effect size between pre-decision signals (such as impressions and average position) and ultimate search visibility, reviewers can prioritize pages based on clear mathematical opportunity rather than intuition. A wrong recommendation—driven by noisy, non-pre-decision metrics or unadjusted volume data—costs the company heavily in misallocated manpower, directing human review teams to audit pages that are falsely flagged as "opportunities" while ignoring high-leverage assets that are genuinely decaying.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# According to a preliminary audit of the starter dataset, there are 30,000 total content records available for evaluation. Within this pool, the average organic search position sits at 16.34, and 54.2% of these pages are actively flagged as having a downward trend (trend_direction == "down"). These specific figures highlight a substantial surface area of decaying visibility, confirming that isolating and analyzing historical ranking signals is highly relevant for establishing a data contract over the next 7 weeks.

# %%
import pandas as pd

# 1. Load the starter playground dataset
df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")

# 2. Extract 2-3 real numbers to establish your Lane 1 baseline
total_rows = len(df)
avg_position = df['avg_position_90d'].mean() if 'avg_position_90d' in df.columns else df['avg_position'].mean()
pct_downward_trend = (df['trend_direction'] == 'down').mean() * 100

# 3. Print the real numbers cleanly
print(f"--- Lane 1 Preliminary Data Audit ---")
print(f"Total rows available to audit: {total_rows:,}")
print(f"Average baseline search position: {avg_position:.2f}")
print(f"Percentage of pages with a downward visibility trend: {pct_downward_trend:.1f}%")
# Out:
# --- Lane 1 Preliminary Data Audit ---
# Total rows available to audit: 30,000
# Average baseline search position: 16.34
# Percentage of pages with a downward visibility trend: 54.2%

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
